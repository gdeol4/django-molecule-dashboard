# %%
import pandas as pd

sidf = pd.read_csv('si.csv')

# %%
import pandas as pd

spdf = pd.read_csv('sp.csv')

# %%
spdf
# Out:
#       id                                target_name      id_chembl id_uniprot  \
# 0     19                                Cathepsin D     CHEMBL2581     P07339
# 1     20             Thyroid hormone receptor alpha     CHEMBL1860     P10827
# 2     21  Transcription intermediary factor 1-alpha  CHEMBL3108638     O15164
# 3     22                Casein kinase II alpha/beta  CHEMBL3038477     P67870
# 4     23                                Cathepsin D     CHEMBL2581     P07339
# ..   ...                                        ...            ...        ...
# 99   118                                Cathepsin D     CHEMBL2581     P07339
# 100  119                     Xanthine dehydrogenase     CHEMBL1929     P47989
# 101  120  Transcription intermediary factor 1-alpha  CHEMBL3108638     O15164
# 102  121                Casein kinase II alpha/beta  CHEMBL3038477     P67870
# 103  122             Thyroid hormone receptor alpha     CHEMBL1860     P10827
#
# ...

# %%
sidf
# Out:
#       id                     target_name id_chembl  \
# 0     43                     Cathepsin D    T67102
# 1     44                     Cathepsin D    T67102
# 2     45  Thyroid hormone receptor alpha    T79591
# 3     46  Thyroid hormone receptor alpha    T79591
# 4     47  Thyroid hormone receptor alpha    T79591
# ..   ...                             ...       ...
# 244  287  Thyroid hormone receptor alpha    T79591
# 245  288  Thyroid hormone receptor alpha    T79591
# 246  289  Thyroid hormone receptor alpha    T79591
# 247  290  Thyroid hormone receptor alpha    T79591
# 248  291                             NaN       NaN
#
#                                          indication  probability  \
# 0                  Hypertension [ICD-11: BA00-BA04]        96.55
# 1                 Multiple sclerosis [ICD-11: 8A40]        96.55
# 2           Congestive heart failure [ICD-11: BD10]        94.99
# 3    High blood cholesterol level [ICD-11: 5C80.00]        94.99
# ...
